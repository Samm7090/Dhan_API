# %%
clienId="1108335715"
accessoken="eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJpc3MiOiJkaGFuIiwicGFydG5lcklkIjoiIiwiZXhwIjoxNzU5MjUxMzIwLCJ0b2tlbkNvbnN1bWVyVHlwZSI6IlNFTEYiLCJ3ZWJob29rVXJsIjoiIiwiZGhhbkNsaWVudElkIjoiMTEwODMzNTcxNSJ9.hnTf_mAYTmMhqembZY5RaXPeLCzBuNloyOEt410KQI4Bkvv46LKgo2wH6Mu58agbHSttQN44sW59M7WKryzLPg"

# %%
pip install dhanhq
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from dhanhq import dhanhq

# %%
dhan = dhanhq(clienId, accessoken)

# %% [markdown]
# To check the weather we logged in or not

# %%
dhan.get_fund_limits()
# Out:
# {'status': 'success',
#  'remarks': '',
#  'data': {'dhanClientId': '1108335715',
#   'availabelBalance': 0.0,
#   'sodLimit': 0.0,
#   'collateralAmount': 0.0,
#   'receiveableAmount': 0.0,
#   'utilizedAmount': 0.0,
#   'blockedPayoutAmount': 0.0,
#   'withdrawableBalance': 0.0}}

# %% [markdown]
# Copy "security Id" from Orders from Dhan API Documentation (Documentation->Left side bar option "Orders-> scroll down and search in table for "SecurityId"->click here->copy the "Compact" link)

# %% [markdown]
# call only 1 row

# %%
import pandas as pd
masterList=pd.read_csv("https://images.dhan.co/api-data/api-scrip-master.csv",nrows=1)
masterList
# Out:
#   SEM_EXM_EXCH_ID SEM_SEGMENT  SEM_SMST_SECURITY_ID SEM_INSTRUMENT_NAME  \
# 0             BSE           C               1026077              FUTCUR
#
#    SEM_EXPIRY_CODE    SEM_TRADING_SYMBOL  SEM_LOT_UNITS SEM_CUSTOM_SYMBOL  \
# 0                0  USDINR-28Aug2024-FUT            1.0    USDINR AUG FUT
#
#        SEM_EXPIRY_DATE  SEM_STRIKE_PRICE SEM_OPTION_TYPE  SEM_TICK_SIZE  \
# 0  2024-08-28 14:30:00             -0.01              XX           0.25
#
#   SEM_EXPIRY_FLAG SEM_EXCH_INSTRUMENT_TYPE  SEM_SERIES SM_SYMBOL_NAME
# 0               M                   FUTCUR         NaN         USDINR

# %%
masterList.columns
# Out:
# Index(['SEM_EXM_EXCH_ID', 'SEM_SEGMENT', 'SEM_SMST_SECURITY_ID',
#        'SEM_INSTRUMENT_NAME', 'SEM_EXPIRY_CODE', 'SEM_TRADING_SYMBOL',
#        'SEM_LOT_UNITS', 'SEM_CUSTOM_SYMBOL', 'SEM_EXPIRY_DATE',
#        'SEM_STRIKE_PRICE', 'SEM_OPTION_TYPE', 'SEM_TICK_SIZE',
#        'SEM_EXPIRY_FLAG', 'SEM_EXCH_INSTRUMENT_TYPE', 'SEM_SERIES',
#        'SM_SYMBOL_NAME'],
#       dtype='object')

# %%
masterList=pd.read_csv("https://images.dhan.co/api-data/api-scrip-master.csv",usecols=masterList.columns,low_memory=False)
masterList
# Out:
#        SEM_EXM_EXCH_ID SEM_SEGMENT  SEM_SMST_SECURITY_ID SEM_INSTRUMENT_NAME  \
# 0                  BSE           C               1026077              FUTCUR
# 1                  BSE           C               1026078              FUTCUR
# 2                  BSE           C               1026079              FUTCUR
# 3                  BSE           C               1026080              FUTCUR
# 4                  BSE           C               1026081              FUTCUR
# ...                ...         ...                   ...                 ...
# 170786             NSE           M                129575              OPTFUT
# 170787             NSE           M                129576              OPTFUT
# 170788             NSE           M                129577              OPTFUT
# 170789             NSE           M                129580              OPTFUT
# 170790             NSE           M                129581              OPTFUT
#
# ...

# %% [markdown]
# Filterout List of Options

# %%
masterList[masterList.SEM_INSTRUMENT_NAME=='OPTIDX']
# Out:
#        SEM_EXM_EXCH_ID SEM_SEGMENT  SEM_SMST_SECURITY_ID SEM_INSTRUMENT_NAME  \
# 12733              BSE           D               1100789              OPTIDX
# 12734              BSE           D               1100798              OPTIDX
# 12735              BSE           D               1100882              OPTIDX
# 12736              BSE           D               1100892              OPTIDX
# 12737              BSE           D               1100908              OPTIDX
# ...                ...         ...                   ...                 ...
# 148020             NSE           D                 89657              OPTIDX
# 148021             NSE           D                 89658              OPTIDX
# 148022             NSE           D                 89659              OPTIDX
# 148027             NSE           D                 89664              OPTIDX
# 148028             NSE           D                 89665              OPTIDX
#
# ...

# %% [markdown]
# Spliting SEM_CUSTOM_SYMBOL column

# %%
masterList[['SYMBOL','EXP_DATE','EXP_MONTH','STRIKE','OPT_TYPE']]= masterList['SEM_CUSTOM_SYMBOL'].str.split(' ',n=4,expand=True)
masterList
# Out:
#        SEM_EXM_EXCH_ID SEM_SEGMENT  SEM_SMST_SECURITY_ID SEM_INSTRUMENT_NAME  \
# 0                  BSE           C               1026077              FUTCUR
# 1                  BSE           C               1026078              FUTCUR
# 2                  BSE           C               1026079              FUTCUR
# 3                  BSE           C               1026080              FUTCUR
# 4                  BSE           C               1026081              FUTCUR
# ...                ...         ...                   ...                 ...
# 170786             NSE           M                129575              OPTFUT
# 170787             NSE           M                129576              OPTFUT
# 170788             NSE           M                129577              OPTFUT
# 170789             NSE           M                129580              OPTFUT
# 170790             NSE           M                129581              OPTFUT
#
# ...

# %% [markdown]
# Now you can see the changes in last column

# %%
masterList[masterList.SEM_INSTRUMENT_NAME=='OPTIDX']
# Out:
#        SEM_EXM_EXCH_ID SEM_SEGMENT  SEM_SMST_SECURITY_ID SEM_INSTRUMENT_NAME  \
# 12733              BSE           D               1100789              OPTIDX
# 12734              BSE           D               1100798              OPTIDX
# 12735              BSE           D               1100882              OPTIDX
# 12736              BSE           D               1100892              OPTIDX
# 12737              BSE           D               1100908              OPTIDX
# ...                ...         ...                   ...                 ...
# 148020             NSE           D                 89657              OPTIDX
# 148021             NSE           D                 89658              OPTIDX
# 148022             NSE           D                 89659              OPTIDX
# 148027             NSE           D                 89664              OPTIDX
# 148028             NSE           D                 89665              OPTIDX
#
# ...

# %% [markdown]
# If you want to Filter some Equity stock segment

# %%
masterList[(masterList.SEM_INSTRUMENT_NAME=='EQUITY') & (masterList.SEM_TRADING_SYMBOL=='SBIN')]   # for SBI Bank
# Out:
#        SEM_EXM_EXCH_ID SEM_SEGMENT  SEM_SMST_SECURITY_ID SEM_INSTRUMENT_NAME  \
# 48131              BSE           E                500112              EQUITY
# 161426             NSE           E                  3045              EQUITY
#
#         SEM_EXPIRY_CODE SEM_TRADING_SYMBOL  SEM_LOT_UNITS  \
# 48131                 0               SBIN            1.0
# 161426                0               SBIN            1.0
#
#           SEM_CUSTOM_SYMBOL SEM_EXPIRY_DATE  SEM_STRIKE_PRICE  ...  \
# 48131   State Bank of India             NaN               NaN  ...
# 161426  State Bank of India             NaN               NaN  ...
#
#        SEM_TICK_SIZE  SEM_EXPIRY_FLAG SEM_EXCH_INSTRUMENT_TYPE SEM_SERIES  \
# 48131            5.0              NaN                       ES          A
# 161426           5.0              NaN                       ES         EQ
#
#              SM_SYMBOL_NAME SYMBOL EXP_DATE EXP_MONTH STRIKE OPT_TYPE
# ...

# %%
masterList[(masterList.SEM_INSTRUMENT_NAME=='EQUITY') & (masterList.SEM_TRADING_SYMBOL=='HDFCNIFTY')]   # for HDFC Bank
# Out:
#        SEM_EXM_EXCH_ID SEM_SEGMENT  SEM_SMST_SECURITY_ID SEM_INSTRUMENT_NAME  \
# 51525              BSE           E                539516              EQUITY
# 155926             NSE           E                 11591              EQUITY
#
#         SEM_EXPIRY_CODE SEM_TRADING_SYMBOL  SEM_LOT_UNITS  SEM_CUSTOM_SYMBOL  \
# 51525                 0          HDFCNIFTY            1.0  HDFC Nifty 50 ETF
# 155926                0          HDFCNIFTY            1.0  HDFC Nifty 50 ETF
#
#        SEM_EXPIRY_DATE  SEM_STRIKE_PRICE  ... SEM_TICK_SIZE  SEM_EXPIRY_FLAG  \
# 51525              NaN               NaN  ...           1.0              NaN
# 155926             NaN               NaN  ...           1.0              NaN
#
#        SEM_EXCH_INSTRUMENT_TYPE SEM_SERIES       SM_SYMBOL_NAME SYMBOL  \
# 51525                       ETF          B     HDFC Mutual Fund   HDFC
# 155926                      ETF         EQ  HDFCAMC - HDFCNIFTY   HDFC
#
#        EXP_DATE EXP_MONTH STRIKE OPT_TYPE
# ...

# %% [markdown]
# Filter Commodity

# %%
masterList[(masterList.SEM_EXM_EXCH_ID == "MCX") & (masterList.SYMBOL=='SILVERMIC') & (masterList.SEM_INSTRUMENT_NAME=='FUTCOM')]   # For Silver
# Out:
#       SEM_EXM_EXCH_ID SEM_SEGMENT  SEM_SMST_SECURITY_ID SEM_INSTRUMENT_NAME  \
# 62823             MCX           M                450659              FUTCOM
# 65588             MCX           M                458305              FUTCOM
# 71670             MCX           M                466029              FUTCOM
#
#        SEM_EXPIRY_CODE       SEM_TRADING_SYMBOL  SEM_LOT_UNITS  \
# 62823                0  SILVERMIC-28Nov2025-FUT            1.0
# 65588                0  SILVERMIC-27Feb2026-FUT            1.0
# 71670                0  SILVERMIC-30Apr2026-FUT            1.0
#
#        SEM_CUSTOM_SYMBOL      SEM_EXPIRY_DATE  SEM_STRIKE_PRICE  ...  \
# 62823  SILVERMIC NOV FUT  2025-11-28 00:00:00               0.0  ...
# 65588  SILVERMIC FEB FUT  2026-02-27 00:00:00               0.0  ...
# 71670  SILVERMIC APR FUT  2026-04-30 00:00:00               0.0  ...
#
#       SEM_TICK_SIZE  SEM_EXPIRY_FLAG SEM_EXCH_INSTRUMENT_TYPE SEM_SERIES  \
# ...

# %%
masterList[(masterList.SEM_EXM_EXCH_ID == "MCX") & (masterList.SYMBOL=='CRUDEOIL') & (masterList.SEM_INSTRUMENT_NAME=='FUTCOM')]      # For CrudeOil
# Out:
#       SEM_EXM_EXCH_ID SEM_SEGMENT  SEM_SMST_SECURITY_ID SEM_INSTRUMENT_NAME  \
# 63516             MCX           M                452373              FUTCOM
# 64783             MCX           M                455865              FUTCOM
# 65538             MCX           M                457886              FUTCOM
# 68570             MCX           M                462523              FUTCOM
# 70698             MCX           M                464925              FUTCOM
# 72616             MCX           M                467013              FUTCOM
#
#        SEM_EXPIRY_CODE      SEM_TRADING_SYMBOL  SEM_LOT_UNITS  \
# 63516                0  CRUDEOIL-19Sep2025-FUT            1.0
# 64783                0  CRUDEOIL-20Oct2025-FUT            1.0
# 65538                0  CRUDEOIL-19Nov2025-FUT            1.0
# 68570                0  CRUDEOIL-18Dec2025-FUT            1.0
# 70698                0  CRUDEOIL-16Jan2026-FUT            1.0
# ...

# %% [markdown]
# Filterout Options Data

# %%
masterList[(masterList.SEM_EXM_EXCH_ID == "NSE") & (masterList.SYMBOL=='NIFTY') & (masterList.OPT_TYPE=='CALL')]
# Out:
#        SEM_EXM_EXCH_ID SEM_SEGMENT  SEM_SMST_SECURITY_ID SEM_INSTRUMENT_NAME  \
# 111136             NSE           D                 35056              OPTIDX
# 111145             NSE           D                 35065              OPTIDX
# 111148             NSE           D                 35068              OPTIDX
# 111178             NSE           D                 35098              OPTIDX
# 111180             NSE           D                 35100              OPTIDX
# ...                ...         ...                   ...                 ...
# 148015             NSE           D                 89652              OPTIDX
# 148017             NSE           D                 89654              OPTIDX
# 148019             NSE           D                 89656              OPTIDX
# 148021             NSE           D                 89658              OPTIDX
# 148027             NSE           D                 89664              OPTIDX
#
# ...

# %% [markdown]
# Filter out Expiry data of SEP month

# %%
masterList[(masterList.SEM_EXM_EXCH_ID == "NSE") & (masterList.SYMBOL=='NIFTY') & (masterList.OPT_TYPE=='CALL') & (masterList.EXP_DATE=='16') & (masterList.EXP_MONTH=='SEP')]
# Out:
#        SEM_EXM_EXCH_ID SEM_SEGMENT  SEM_SMST_SECURITY_ID SEM_INSTRUMENT_NAME  \
# 111136             NSE           D                 35056              OPTIDX
# 111817             NSE           D                 35824              OPTIDX
# 111821             NSE           D                 35828              OPTIDX
# 111823             NSE           D                 35830              OPTIDX
# 111832             NSE           D                 35840              OPTIDX
# ...                ...         ...                   ...                 ...
# 116437             NSE           D                 46496              OPTIDX
# 116613             NSE           D                 47177              OPTIDX
# 120051             NSE           D                 52075              OPTIDX
# 120053             NSE           D                 52077              OPTIDX
# 120055             NSE           D                 52079              OPTIDX
#
# ...

# %% [markdown]
# PlaceOrder

# %%
dhan.place_order(security_id='11591',            # HDFC Bank and copy the security id from the SBIN data we fetched
    exchange_segment=dhan.NSE,
    transaction_type=dhan.BUY,
    quantity=10,
    order_type=dhan.MARKET,
    product_type=dhan.INTRA,
    price=0)
# Out:
# {'status': 'failure',
#  'remarks': {'error_code': 'DH-906',
#   'error_type': 'Order_Error',
#   'error_message': 'Market is Closed! Want to place an offline order?'},
#  'data': {'errorType': 'Order_Error',
#   'errorCode': 'DH-906',
#   'errorMessage': 'Market is Closed! Want to place an offline order?'}}

# %% [markdown]
# Order Placed List

# %%
dhan.get_order_list()   # If placed any order you will get the data
# Out:
# {'status': 'success', 'remarks': '', 'data': []}

# %% [markdown]
# To Get the Positions

# %%
dhan.get_positions()
# Out:
# {'status': 'success', 'remarks': '', 'data': []}

# %% [markdown]
# You can see the tradebook

# %%
dhan.get_trade_book()
# Out:
# {'status': 'success', 'remarks': '', 'data': []}

# %% [markdown]
# Cancel the Order requires Order Id if you have place any

# %%
#dhan.cancel_order(order_id)
